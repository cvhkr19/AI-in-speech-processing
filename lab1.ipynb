# %%
import librosa

# %%
y, sr = librosa.load("ai in speech processing.wav")

# %%
librosa.display.waveshow(y,color = 'blue')

# %%
print(y)
print(sr)
# for spoken words the amplitude spikes high, for silence it is a flat curve.
# Out:
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.5882303e-07
#   4.7751133e-08  0.0000000e+00]
# 22050

# %%
from IPython.display import Audio
Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(y,rate = 44500)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(len(y))
# Out:
# 59271

# %%
segment = y[20000:50000]
Audio(segment,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
reverse = np.flipud(y)
Audio(reverse,rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(reverse,rate = 15000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
